# %% [markdown]
# <a href="https://colab.research.google.com/github/sebr22/sebr/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sebr22/sebr/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# The lane i have chosen is *Refresh / Content Opportunity Scoring*. The question is: Can we use observable data on page, search, and engagement numbers in order to rank pages (with scores) on which should be reviewed for content-refresh first more effectively than a 'by-hand' rule?
#
# I like this lane as it feels like a logical continuation of the work looked at already, which I felt comfortable working on and felt as though I was developing some new skills, which I would like to continue. I also have some experience working with random forests and logistic regressions from my degree so would be interested in implementing these into real-world scenarios and further developing my knowledge of them.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The work will improve the decision on which pages should be reviewed first for a potential refresh when there is a limited amount of time available. The people acting on this decision would be an SEO manager or someone in a similar role, who would be able to use this decision to prioritise their time more effectively. A wrong recommendation would result in potentially wasted time reviewing a page that does not provide a good opportunity to increase traffic/engagement; thereby potentially missing an opportunity to update a page that could increase traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# An example of some numbers that show the value in such a project are:
#
# - The number of pages included in the starter data set is already 30,000, this would clearly be very time consuming to go through all of these pages and decide whether a content refresh may be necessary, hence there is clearly value in developing a ranking of the pages which shows how the review process should be prioritised.
#
# - For example, if we take impressions_90d, the 25th percentile value is 81 and the 75th percentile value is 3615.25. This massive difference in size between the two numbers illustrates an opportunity to prioritise pages based on the potential impact a refresh could have on impressions
#
# These examples suggest that a team shouldn't treat every page equally and an ML ranking model could help prioritize limited time.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

len(df)

df[[
    "impressions_90d",
    "avg_position",
    "ctr",
    "content_age_days",
    "days_since_last_update"
]].describe().T
# Out:
#                           count         mean           std   min    25%  \
# impressions_90d         30000.0  5200.366300  16838.019547   1.0   81.0
# avg_position            30000.0    16.342380     15.216790   0.0    6.2
# ctr                     30000.0     0.510733      3.279162   0.0    0.0
# content_age_days        30000.0   256.167800    132.707930  90.0  132.0
# days_since_last_update  30000.0    46.098300     42.078709   1.0   20.0
#
#                            50%      75%       max
# impressions_90d         731.00  3615.25  517715.0
# avg_position             10.80    22.30     245.0
# ctr                       0.07     0.29     100.0
# content_age_days        236.00   333.00     564.0
# days_since_last_update   20.00   104.00     373.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# The work will be able to identify patterns in page, search, and engagement numbers, support decisions by ranking which pages it may be worth reviewing first for a content refresh in order to help prioritise time, and understand which signals contribute to a recommendation. It won't provide causal proof that refreshing pages will definitely improve performance, prove that a recommended refresh resulted in a later increase in impressions/engagement, nor predict Google’s ranking decisions. Hence, model results need to be interpreted as evidence for reviews and not as certainty about what will happen after a content refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
